# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
flight=pd.read_csv(r"C:\Users\greep\Downloads\Flight_Booking.csv")

# %%
flight
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
flight.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        300153 non-null  int64
#  1   airline           300153 non-null  object
#  2   flight            300153 non-null  object
#  3   source_city       300153 non-null  object
#  4   departure_time    300153 non-null  object
#  5   stops             300153 non-null  object
#  6   arrival_time      300153 non-null  object
#  7   destination_city  300153 non-null  object
#  8   class             300153 non-null  object
#  9   duration          300153 non-null  float64
#  10  days_left         300153 non-null  int64
#  11  price             300153 non-null  int64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 27.5+ MB

# %%
flight.shape
# Out:
# (300153, 11)

# %%
flight.isnull().sum()
# Out:
# Unnamed: 0          0
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
flight.duplicated().sum()
# Out:
# 0

# %%
flight.head(10)
# Out:
#    Unnamed: 0   airline   flight source_city departure_time stops  \
# 0           0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1           1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2           2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3           3   Vistara   UK-995       Delhi        Morning  zero
# 4           4   Vistara   UK-963       Delhi        Morning  zero
# 5           5   Vistara   UK-945       Delhi        Morning  zero
# 6           6   Vistara   UK-927       Delhi        Morning  zero
# 7           7   Vistara   UK-951       Delhi      Afternoon  zero
# 8           8  GO_FIRST   G8-334       Delhi  Early_Morning  zero
# 9           9  GO_FIRST   G8-336       Delhi      Afternoon  zero
#
#     arrival_time destination_city    class  duration  days_left  price
# 0          Night           Mumbai  Economy      2.17          1   5953
# 1        Morning           Mumbai  Economy      2.33          1   5953
# ...

# %%
flight.drop(columns='Unnamed: 0',inplace=True)

# %%
flight
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
flight.describe()
# Out:
#             duration      days_left          price
# count  300153.000000  300153.000000  300153.000000
# mean       12.221021      26.004751   20889.660523
# std         7.191997      13.561004   22697.767366
# min         0.830000       1.000000    1105.000000
# 25%         6.830000      15.000000    4783.000000
# 50%        11.250000      26.000000    7425.000000
# 75%        16.170000      38.000000   42521.000000
# max        49.830000      49.000000  123071.000000

# %%
# Data Visualisation

# %%
flight
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
flight['airline'].unique()
# Out:
# array(['SpiceJet', 'AirAsia', 'Vistara', 'GO_FIRST', 'Indigo',
#        'Air_India'], dtype=object)

# %%
# Dayleft vs price
sns.relplot(x=flight['days_left'],y=flight['price'],kind='line',data=flight,height=6,aspect=3)
# From the line chart we can clearly say that as the no of days increases the flight price decreases
# Out:
# C:\Users\greep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
avg_price=flight.groupby('airline')['price'].mean()
avg_price.plot.bar()
# From the graph we can clearly saw that the avg price of Vistara is high and the avg price of Air Asia is the lowest
# Out:
# <Axes: xlabel='airline'>

# %%
# Stops vs Price
sns.barplot(x=flight['stops'],y=flight['price'])
# From the bar graph we can conclude that the price of one stops flight is higher when compared to zero stops or two or more
# Out:
# <Axes: xlabel='stops', ylabel='price'>

# %%
# Business,Economy class,flight vs price
sns.barplot(x=flight['class'],y=flight['price'],data=flight,hue='airline')
# From the graph we can conclude that only Vistara and AirIndia has Business Class Tickets
# Out:
# <Axes: xlabel='class', ylabel='price'>

# %%
flight
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
#Range of price of flights with source and destination city according to the days left

sns.relplot(x=flight['days_left'],y=flight['price'],data=flight,kind='line',hue='source_city')
# Out:
# C:\Users\greep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(x=flight['days_left'],y=flight['price'],data=flight,kind='line',hue='source_city')
# Out:
# C:\Users\greep\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Count of No flights operated by each airlines
plt.bar(flight['airline'].unique(),height=flight['airline'].value_counts())
# More no of Flights operated by SpiceJet least by Air_India
# Out:
# <BarContainer object of 6 artists>

# %%
# Frequency distribution of price
plt.hist(flight['price'],bins=5,color='green')
# Out:
# (array([2.1009e+05, 3.0578e+04, 5.5307e+04, 4.0480e+03, 1.3000e+02]),
#  array([  1105. ,  25498.2,  49891.4,  74284.6,  98677.8, 123071. ]),
#  <BarContainer object of 5 artists>)

# %%
# percentage of flights flying to the Source city
plt.pie(flight['source_city'].value_counts(),labels=flight['source_city'].unique(),autopct='%.2f%%')
# More no of flights are strating from Mumbai and least from Hyderabad
# Out:
# ([<matplotlib.patches.Wedge at 0x1b056736110>,
# ...
#  [Text(0.8809535489223089, 0.6587266843245301, 'Delhi'),
#   Text(-0.3779004059372413, 1.0330495066512875, 'Mumbai'),
#   Text(-1.0992131326110681, 0.04159914777206989, 'Bangalore'),
#   Text(-0.6015577367721227, -0.9209388086781889, 'Kolkata'),
#   Text(0.36016745105880016, -1.0393649056985748, 'Hyderabad'),
#   Text(1.0109871514258975, -0.43348007987882137, 'Chennai')],
#  [Text(0.4805201175939866, 0.35930546417701636, '20.44%'),
#   Text(-0.20612749414758613, 0.5634815490825203, '20.29%'),
#   Text(-0.5995707996060371, 0.02269044423931085, '17.34%'),
#   Text(-0.32812240187570324, -0.5023302592790121, '15.44%'),
#   Text(0.19645497330480005, -0.5669263121992225, '13.60%'),
#   Text(0.5514475371413986, -0.23644367993390253, '12.89%')])

# %%
# Comparing of flights reaching the destination city
plt.bar(flight['destination_city'].unique(),height=flight['destination_city'].value_counts())
# Out:
# <BarContainer object of 6 artists>

# %%
# Checking the density distribution of Price
sns.kdeplot(flight['price'])
# Out:
# <Axes: xlabel='price', ylabel='Density'>

# %%
# Finding the correlation of the dataset
sns.heatmap(flight.corr(numeric_only=True),cmap='coolwarm',annot=True)
# There are no high correlated data
# Out:
# <Axes: >

# %%
flight
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
# Checking for Outliers in the dataset

# %%
flight.dtypes
# Out:
# airline              object
# flight               object
# source_city          object
# departure_time       object
# stops                object
# arrival_time         object
# destination_city     object
# class                object
# duration            float64
# days_left             int64
# price                 int64
# dtype: object

# %%
for col in flight.columns:
    if flight[col].dtypes!='object':
        sns.boxplot(flight[col])
        plt.xlabel(col)

# %%
# Removing the outliers using IQR method

# %%
Q1=flight['price'].quantile(0.25)
Q3=flight['price'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Q1-(1.5*IQR)
upper_bound=Q3+(1.5*IQR)

# %%
flight=flight[(flight['price']>=lower_bound) & (flight['price']<=upper_bound)]

# %%
flight
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
for col in flight.columns:
    if flight[col].dtypes!='object':
        sns.boxplot(flight[col])
        plt.xlabel(col)

# %%
# Converting categorical column to Numerical for applying Machine Learning Algorithms
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
for col in flight.columns:
    if flight[col].dtypes=='object':
        flight[col]=le.fit_transform(flight[col])
# Out:
# C:\Users\greep\AppData\Local\Temp\ipykernel_4308\565674384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight[col]=le.fit_transform(flight[col])
# C:\Users\greep\AppData\Local\Temp\ipykernel_4308\565674384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   flight[col]=le.fit_transform(flight[col])
# C:\Users\greep\AppData\Local\Temp\ipykernel_4308\565674384.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
flight
# Out:
#         airline  flight  source_city  departure_time  stops  arrival_time  \
# 0             4    1408            2               2      2             5
# 1             4    1387            2               1      2             4
# 2             0    1213            2               1      2             1
# 3             5    1559            2               4      2             0
# 4             5    1549            2               4      2             4
# ...         ...     ...          ...             ...    ...           ...
# 300148        5    1477            1               4      0             2
# 300149        5    1481            1               0      0             5
# 300150        5    1486            1               1      0             5
# 300151        5    1483            1               1      0             2
# 300152        5    1477            1               4      0             2
#
#         destination_city  class  duration  days_left  price
# ...

# %%
# Splitting the datas into X and Y to apply ML models
X=flight.iloc[:,0:10]
y=flight.iloc[:,-1]

# %%
X
# Out:
#         airline  flight  source_city  departure_time  stops  arrival_time  \
# 0             4    1408            2               2      2             5
# 1             4    1387            2               1      2             4
# 2             0    1213            2               1      2             1
# 3             5    1559            2               4      2             0
# 4             5    1549            2               4      2             4
# ...         ...     ...          ...             ...    ...           ...
# 300148        5    1477            1               4      0             2
# 300149        5    1481            1               0      0             5
# 300150        5    1486            1               1      0             5
# 300151        5    1483            1               1      0             2
# 300152        5    1477            1               4      0             2
#
#         destination_city  class  duration  days_left
# ...

# %%
y
# Out:
# 0          5953
# 1          5953
# 2          5956
# 3          5955
# 4          5955
#           ...
# 300148    69265
# 300149    77105
# 300150    79099
# 300151    81585
# 300152    81585
# Name: price, Length: 300030, dtype: int64

# %%
# Detecting Multicollinearity and removing the Multicollinear Features
from statsmodels.stats.outliers_influence import variance_inflation_factor
Vif=pd.DataFrame()

# %%
Vif['feature']=X.columns

# %%
Vif
# Out:
#             feature
# 0           airline
# 1            flight
# 2       source_city
# 3    departure_time
# 4             stops
# 5      arrival_time
# 6  destination_city
# 7             class
# 8          duration
# 9         days_left

# %%
vif=[variance_inflation_factor(X.values,i) for i in range(len(X.columns))]

# %%
vif
# Out:
# [6.697557712863813,
#  12.66755082583874,
#  2.9691591192227222,
#  2.8056938422809696,
#  1.4375257092751488,
#  3.7843633393616765,
#  2.9188311667430975,
#  2.8537107632511574,
#  4.75434028056495,
#  4.074288431127075]

# %%
Vif['result']=vif

# %%
Vif
# Out:
#             feature     result
# 0           airline   6.697558
# 1            flight  12.667551
# 2       source_city   2.969159
# 3    departure_time   2.805694
# 4             stops   1.437526
# 5      arrival_time   3.784363
# 6  destination_city   2.918831
# 7             class   2.853711
# 8          duration   4.754340
# 9         days_left   4.074288

# %%
# Dropping the column which has Vif value > 5
X.drop(columns='flight',inplace=True)

# %%
X
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 0             4            2               2      2             5
# 1             4            2               1      2             4
# 2             0            2               1      2             1
# 3             5            2               4      2             0
# 4             5            2               4      2             4
# ...         ...          ...             ...    ...           ...
# 300148        5            1               4      0             2
# 300149        5            1               0      0             5
# 300150        5            1               1      0             5
# 300151        5            1               1      0             2
# 300152        5            1               4      0             2
#
#         destination_city  class  duration  days_left
# 0                      5      1      2.17          1
# 1                      5      1      2.33          1
# ...

# %%
vif=pd.DataFrame(X.columns,columns=['feature'])

# %%
vif
# Out:
#             feature
# 0           airline
# 1       source_city
# 2    departure_time
# 3             stops
# 4      arrival_time
# 5  destination_city
# 6             class
# 7          duration
# 8         days_left

# %%
variance=[ variance_inflation_factor(X.values,i) for i in range(len(X.columns))]

# %%
vif['result']=variance

# %%
vif
# Out:
#             feature    result
# 0           airline  3.392145
# 1       source_city  2.927441
# 2    departure_time  2.779140
# 3             stops  1.426818
# 4      arrival_time  3.684086
# 5  destination_city  2.885422
# 6             class  2.851025
# 7          duration  4.113884
# 8         days_left  3.979348

# %%
# Splitting into Training and Testing Datas and Applying Linear Regression Algorithm to predict the future results
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42,test_size=0.2)

# %%
X_train
# Out:
#         airline  source_city  departure_time  stops  arrival_time  \
# 106816        1            0               4      0             2
# 116290        5            0               4      0             5
# 233527        1            5               1      0             5
# 114950        3            0               4      2             4
# 30300         1            2               4      1             5
# ...         ...          ...             ...    ...           ...
# 119879        5            4               2      0             0
# 259237        1            0               1      0             1
# 131932        1            4               5      0             4
# 146867        2            4               0      0             5
# 121958        1            4               0      0             4
#
#         destination_city  class  duration  days_left
# 106816                 4      1      8.75         30
# 116290                 1      1     10.50         11
# ...

# %%
y_train
# Out:
# 106816     7004
# 116290    12454
# 233527    54608
# 114950     2343
# 30300      9831
#           ...
# 119879    22869
# 259237    43865
# 131932     5102
# 146867     5574
# 121958     6339
# Name: price, Length: 240024, dtype: int64

# %%
# Standardising to bring all the Values in the data frame to a single scale
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
X_train.shape
# Out:
# (240024, 9)

# %%
X_test.shape
# Out:
# (60006, 9)

# %%
# Applying Linear Regression Model
from sklearn.linear_model import LinearRegression
lin=LinearRegression()

# %%
# Training the dataset
lin.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Testing using the testing set
y_pred=lin.predict(X_test)

# %%
# Calculating the performace of the model
from sklearn.metrics import *

# %%
# Evaluating the performance of the model using the R2_scores,MAE,RMSE
r2_score(y_test,y_pred)
# Out:
# 0.9061556333613725

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 4602.2739264302245

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 6919.498329377373

# %%
# The model can accurately predict 90% of the result correctly

# %%
result=pd.DataFrame(y_test)

# %%
result['predicted_price']=y_pred

# %%
result
# Out:
#         price  predicted_price
# 199729   5042      8017.283693
# 139746   6109      5860.836378
# 54736    5103      9568.027049
# 9515     5087      4496.139864
# 18040    4007      4742.497380
# ...       ...              ...
# 87321    4294      7150.913636
# 86364    7489      3024.468658
# 137743   4497      7674.686773
# 188095   8875     10319.080018
# 88751    3685      6616.583947
#
# [60006 rows x 2 columns]

# %%
# Predicting the price with powerful model like Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DR=DecisionTreeRegressor()

# %%
DR.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=DR.predict(X_test)

# %%
from sklearn.metrics import *

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9775166602886016

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 3386.8886312050204

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1125.7074709195747

# %%
result=pd.DataFrame(y_test)

# %%
result['predicted_price']=y_pred

# %%
result
# Out:
#         price  predicted_price
# 199729   5042           5042.0
# 139746   6109           6109.0
# 54736    5103           6017.0
# 9515     5087           6042.0
# 18040    4007          11237.0
# ...       ...              ...
# 87321    4294           4294.0
# 86364    7489           7489.0
# 137743   4497           6489.0
# 188095   8875           8140.0
# 88751    3685           3685.0
#
# [60006 rows x 2 columns]

# %%
# The prediction that we get from decision Tree Regressor is better when compared to Linear Regression

# %%
# Predicting the flights price with Random Forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RF=RandomForestRegressor()

# %%
RF.fit(X_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred=RF.predict(X_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.9861332467350903

# %%
np.sqrt(mean_squared_error(y_test,y_pred))
# Out:
# 2659.854614334369

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1051.8562032269415

# %%
result=pd.DataFrame(y_test)

# %%
result['predicted_price']=y_pred

# %%
result
# Out:
#         price  predicted_price
# 199729   5042          5472.50
# 139746   6109          6109.00
# 54736    5103          7987.28
# 9515     5087          5652.22
# 18040    4007          5121.46
# ...       ...              ...
# 87321    4294          4319.40
# 86364    7489          7506.65
# 137743   4497          5519.09
# 188095   8875          9309.95
# 88751    3685          3738.34
#
# [60006 rows x 2 columns]

# %%
# The model performs better in Random Forest than Decision Tree
# In Random Forest Regressor we get the model with the best r2_score of 98%
